# %% [markdown]
# <a href="https://colab.research.google.com/github/Aya-Nabil11/-Learn-Python-Programming---Beginner-to-Master/blob/main/Aya_nabil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('thank u')
